# %%
# imports
import numpy as np
import matplotlib.pyplot as plt
import mesaPlot as mp
import pandas as pd


# data files
data_file1 = 'part_1' # part one uses 0.02 metalicity, 20 msol

# %%
colors = [
        'steelblue',  # steel blue
        'firebrick',  # firetruck
        '#008080',  # Teal
        'k',  # black
        'magenta', # magenta
        'green',  # Dark Blue
        '#FFFF00',  # Yellow
        '#800080',  # Purple
        '#40E0D0',  # Turquoise
        '#A52A2A'   # Brown
    ]

# %%
# load data
data = mp.MESA() #this creates an empty data container 
data.loadHistory(data_file1)
print(data.hist.keys()) # Lists available data values
data = {'center_h1': data.hist.center_h1,
        'center_he4': data.hist.center_he4, 
        'center_c12': data.hist.center_c12,
        'center_o16': data.hist.center_o16,
        'center_n14': data.hist.center_n14,
        'star_age':  data.hist.star_age} # choose what data parts we want
data_df = pd.DataFrame(data)
# Out:
# ['model_number', 'num_zones', 'star_age', 'log_dt', 'star_mass', 'log_xmstar', 'log_abs_mdot', 'mass_conv_core', 'conv_mx1_top', 'conv_mx1_bot', 'conv_mx2_top', 'conv_mx2_bot', 'mx1_top', 'mx1_bot', 'mx2_top', 'mx2_bot', 'log_LH', 'log_LHe', 'log_LZ', 'log_Lnuc', 'pp', 'cno', 'tri_alfa', 'epsnuc_M_1', 'epsnuc_M_2', 'epsnuc_M_3', 'epsnuc_M_4', 'epsnuc_M_5', 'epsnuc_M_6', 'epsnuc_M_7', 'epsnuc_M_8', 'he_core_mass', 'co_core_mass', 'one_core_mass', 'fe_core_mass', 'neutron_rich_core_mass', 'log_Teff', 'log_L', 'log_R', 'log_g', 'v_div_csound_surf', 'log_cntr_P', 'log_cntr_Rho', 'log_cntr_T', 'center_mu', 'center_ye', 'center_abar', 'center_h1', 'center_he4', 'center_c12', 'center_o16', 'center_n14', 'surface_c12', 'surface_o16', 'total_mass_h1', 'total_mass_he4', 'num_retries', 'num_iters', 'version_number', 'compiler', 'build', 'MESA_SDK_version', 'math_backend', 'date', 'burn_min1', 'burn_min2', 'msun', 'rsun', 'lsun']

# %%
data_df
# Out:
#      center_h1  center_he4  center_c12  center_o16    center_n14      star_age
# 0          0.7    0.279970    0.003447    0.009381  1.010343e-03  1.000000e-05
# 1          0.7    0.279970    0.003447    0.009381  1.010343e-03  7.441600e-05
# 2          0.7    0.279970    0.003447    0.009381  1.010343e-03  2.595868e-04
# 3          0.7    0.279970    0.003447    0.009381  1.010343e-03  7.203511e-04
# 4          0.7    0.279970    0.003447    0.009381  1.010343e-03  1.866880e-03
# ..         ...         ...         ...         ...           ...           ...
# 192        0.0    0.007630    0.242649    0.724545  1.661507e-13  1.079179e+07
# 193        0.0    0.005893    0.236567    0.732070  1.780173e-13  1.079375e+07
# 194        0.0    0.004454    0.231319    0.738400  2.001489e-13  1.079544e+07
# 195        0.0    0.003149    0.226290    0.744244  1.493647e-13  1.079707e+07
# 196        0.0    0.000903    0.215682    0.754640  0.000000e+00  1.080055e+07
#
# [197 rows x 6 columns]

# %%
# Plot star age vs center_he4
non_zero_index = np.nonzero(data_df['center_h1'].values - data_df['center_h1'][0])
t0_main = data_df['star_age'][non_zero_index[0][0]]

plt.figure(figsize=(8,6), ) #dpi=300)
plt.plot(data_df['star_age'] - t0_main, data_df['center_h1'], label=f'H', color=colors[0], linestyle='--')
plt.plot(data_df['star_age'] - t0_main, data_df['center_he4'], label='He', color=colors[1], linestyle='-.')

plt.xlabel('Star Age (Years)', size=15)
plt.ylabel('Mass Fraction', size=15)
plt.title('Fraction of H & He Vs Star Age', size =15)
plt.xscale('log')
#plt.xlim(0, np.max(data_df['star_age']) - t0_main)
#plt.yscale('log')
plt.legend()
plt.show()

# %%
# Plot star age vs center_he4
non_zero_index = np.nonzero(data_df['center_h1'].values - data_df['center_h1'][0])
t0_main = data_df['star_age'][non_zero_index[0][0]]

plt.figure(figsize=(8,6),) #)dpi=300)
#center_n14
plt.plot(data_df['star_age'] - t0_main, data_df['center_c12'], label=f'center_c12', color=colors[2], linestyle='--')
plt.plot(data_df['star_age'] - t0_main, data_df['center_n14'], label='center_n14', color=colors[3], linestyle='-.')
plt.plot(data_df['star_age'] - t0_main, data_df['center_o16'], label='center_o16', color=colors[4], linestyle=':')

plt.xlabel('Star Age (Years)', size=15)
plt.ylabel('Mass Fraction', size=15)
plt.title('Fraction Vs Star Age', size =15)
plt.xscale('log')
plt.yscale('log')
#plt.xlim(0, np.max(data_df['star_age']) - t0_main)
#plt.yscale('log')
plt.legend()
plt.show()

# %%
# Plot star age vs center_he4
non_zero_index = np.nonzero(data_df['center_h1'].values - data_df['center_h1'][0])
t0_main = data_df['star_age'][non_zero_index[0][0]]

plt.figure(figsize=(8,6),) #)dpi=300)
#center_n14
plt.plot(data_df['star_age'] - t0_main, data_df['center_c12'], label=f'center_c12', color=colors[2], linestyle='--')
plt.plot(data_df['star_age'] - t0_main, data_df['center_he4'], label='He', color=colors[1], linestyle='-.')
plt.plot(data_df['star_age'] - t0_main, data_df['center_o16'], label='center_o16', color=colors[4], linestyle=':')

plt.xlabel('Star Age (Years)', size=15)
plt.ylabel('Mass Fraction', size=15)
plt.title('Fraction Vs Star Age', size =15)
plt.xscale('log')
plt.yscale('log')

plt.xlim(10**6.6, np.max(data_df['star_age']))
#plt.xlim(0, np.max(data_df['star_age']) - t0_main)
#plt.yscale('log')
plt.legend()
plt.show()
